# %%
import numpy as np

X = np.array([100, 200, 300, 400, 500, 6000])
X_transformed = np.log1p(X)

X_transformed
# Out:
# array([4.61512052, 5.30330491, 5.70711026, 5.99396143, 6.2166061 ,
#        8.6996814 ])

# %%
import matplotlib.pyplot as plt
plt.hist(X)
# Out:
# (array([5., 0., 0., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 100.,  690., 1280., 1870., 2460., 3050., 3640., 4230., 4820.,
#         5410., 6000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(X_transformed)
# Out:
# (array([1., 1., 1., 2., 0., 0., 0., 0., 0., 1.]),
#  array([4.61512052, 5.02357661, 5.43203269, 5.84048878, 6.24894487,
#         6.65740096, 7.06585705, 7.47431314, 7.88276922, 8.29122531,
#         8.6996814 ]),
#  <BarContainer object of 10 artists>)

# %%
from sklearn.preprocessing import PowerTransformer

pt = PowerTransformer(method="box-cox")

X = np.array([100, 200, 300, 400, 500, 6000])
X_transformed = pt.fit_transform(X.reshape(-1, 1))
X_transformed
# Out:
# array([[-1.59609055],
#        [-0.57733648],
#        [-0.10557144],
#        [ 0.18352382],
#        [ 0.38484813],
#        [ 1.71062653]])
