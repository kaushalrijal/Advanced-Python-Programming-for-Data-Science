# %%
import pandas as pd

df = pd.DataFrame({
    'Date': ['2025-01-11', '2025-01-12', '2025-01-13', '2025-01-14' ],
    'Sales': [101, 105,  119, 200]
})

df.dtypes
# Out:
# Date     object
# Sales     int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date     datetime64[ns]
# Sales             int64
# dtype: object

# %%
df = df.set_index('Date')
df
# Out:
#             Sales
# Date
# 2025-01-11    101
# 2025-01-12    105
# 2025-01-13    119
# 2025-01-14    200

# %%
df['Year'] = df.index.year
df['Month'] = df.index.month
df['Day'] = df.index.day
df['Day_Name'] = df.index.day_name()
df['Month_Name'] = df.index.month_name()

df.head()
# Out:
#             Sales  Year  Month  Day  Day_Name Month_Name
# Date
# 2025-01-11    101  2025      1   11  Saturday    January
# 2025-01-12    105  2025      1   12    Sunday    January
# 2025-01-13    119  2025      1   13    Monday    January
# 2025-01-14    200  2025      1   14   Tuesday    January

# %%
df.loc['2025-01']
# Out:
#             Sales  Year  Month  Day  Day_Name Month_Name
# Date
# 2025-01-11    101  2025      1   11  Saturday    January
# 2025-01-12    105  2025      1   12    Sunday    January
# 2025-01-13    119  2025      1   13    Monday    January
# 2025-01-14    200  2025      1   14   Tuesday    January

# %%
df.plot.bar(x='Day_Name', y="Sales")
# Out:
# <Axes: xlabel='Day_Name'>
