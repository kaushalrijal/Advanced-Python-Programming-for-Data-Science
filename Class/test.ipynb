# %%
# !pip install requests zeep
# Out:
# zsh:1: /Users/mac/Documents/Code/Python/College/Advanced Python Programming For Data Science/Class/env/bin/pip: bad interpreter: /Users/mac/Documents/Code/Python/Elective/Class/env/bin/python3.13: no such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 14.4 MB/s eta 0:00:00m eta 0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [zeep]━━━━━━━━━━━━━ 1/7 [lxml]
# ...

# %%
# !pip install beautifulsoup4
# Out:
# zsh:1: /Users/mac/Documents/Code/Python/College/Advanced Python Programming For Data Science/Class/env/bin/pip: bad interpreter: /Users/mac/Documents/Code/Python/Elective/Class/env/bin/python3.13: no such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [beautifulsoup4]
# ...

# %%
# !pip install selenium
# Out:
# zsh:1: /Users/mac/Documents/Code/Python/College/Advanced Python Programming For Data Science/Class/env/bin/pip: bad interpreter: /Users/mac/Documents/Code/Python/Elective/Class/env/bin/python3.13: no such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 3.0 MB/s eta 0:00:002.8 MB/s eta 0:00:01
# ...
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2025.7.14
#     Uninstalling certifi-2025.7.14:
#       Successfully uninstalled certifi-2025.7.14
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [selenium]  9/10 [selenium]
# ...

# %%
# !pip install pandas requests sqlalchemy psycopg2-binary pymongo beautifulsoup4 lxml dask pydantic
# Out:
# zsh:1: /Users/mac/Documents/Code/Python/College/Advanced Python Programming For Data Science/Class/env/bin/pip: bad interpreter: /Users/mac/Documents/Code/Python/Elective/Class/env/bin/python3.13: no such file or directory
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 3.3 MB/s eta 0:00:00MB/s eta 0:00:01:030m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.6 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 9.3 MB/s eta 0:00:009.6 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.7/920.7 kB 9.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 10.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 12.8 MB/s eta 0:00:00 MB/s eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21/21 [dask]37m━ 20/21 [dask]s]c]spython]]
# ...

# %%
import lxml
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import lxml
#
# ModuleNotFoundError: No module named 'lxml'

# %%
# !pip install lxml
# Out:
# zsh:1: /Users/mac/Documents/Code/Python/College/Advanced Python Programming For Data Science/Class/env/bin/pip: bad interpreter: /Users/mac/Documents/Code/Python/Elective/Class/env/bin/python3.13: no such file or directory
# ...
