# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
X = np.arange(1, 30, 0.27)
y = 1.123*np.square(X) + 2.456

plt.figure(figsize=(6,4))
plt.plot(X, y)
plt.xlabel("X")
plt.ylabel('y')
plt.title("X vs y")
plt.grid()
plt.show()

# %%
# Plots using subplots
fig= plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.plot(X, y, c="r")
ax1.set_xlabel("X")
ax1.set_ylabel('y')
ax1.set_title("X vs y");

ax2 = fig.add_subplot(2, 2, 2)
ax2.plot(X, y, c="b")
ax2.set_xlabel("X")
ax2.set_ylabel('y')
ax2.set_title("X vs y");

plt.tight_layout()

# %%
fruits = ["Apples", "Bananas", "Oranges", "Guava"]
quantities = [100, 120, 90, 130]

fig, axes = plt.subplots(2,2)

for i in range(2):
    for j in range(2):
        axes[i, j].bar(fruits, quantities, color=['Red', 'Yellow', "Orange", "Green"], alpha=0.7)
        axes[i, j].set_title(f"Plot {i}, {j}")
        axes[i, j].set_xticks(ticks=fruits)
        axes[i, j].set_xticklabels(labels=fruits, rotation=45);

plt.tight_layout()
# fig.subplots_adjust(wspace=0.15, hspace=0.35)

# %%
# generate sample data
data = np.random.normal(loc=50, scale=10, size=1000)

# create histogram
plt.hist(data, bins=20, color="skyblue", edgecolor="black")

# labels and title
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Histogram of Random Data")

plt.show()

# %%
from sklearn.datasets import make_moons

X, y = make_moons(
    n_samples=1000,
    noise=0.03,
    random_state=42
)

fig, axes = plt.subplots()
axes.scatter(X[:, 0], X[:, 1], c=y);
axes.text(x=0.6, y=1, s="Hello World", family="monospace", fontsize=10);
axes.set_title("Scatter Plot")
plt.savefig("scatter.pdf")

# %%
from sklearn.datasets import load_iris

X, y = load_iris(return_X_y=True, as_frame=True)

# data.data.info()
# X = data.data
# y = data.target

# feature_names = data.feature_names
# class_names = data.target_names

# print(feature_names)
# print(class_names)

print(X.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
y.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int64>

# %%
fig, axes = plt.subplots(2, 2)

# for i in range(2):
#     for j in range(2):
#         axes[i, j].bar(fruits, quantities, color=['Red', 'Yellow', "Orange", "Green"], alpha=0.7)
#         axes[i, j].set_title(f"Plot {i}, {j}")
#         axes[i, j].set_xticks(ticks=fruits)
#         axes[i, j].set_xticklabels(labels=fruits, rotation=45);

ax1 = axes[0,0]
ax2 = axes[0,1]
ax3 = axes[1,0]
ax4 = axes[1,1]

ax1.bar(x=["Setosa", "Versicolor", "Virginica"], 
         height=y.value_counts(), color=["Red", "Green", "Blue"]
        )
ax1.set_title("Species Distribution", fontsize=8)

ax2.scatter(X['sepal length (cm)'], X['petal length (cm)'], c=y)
ax2.set_title("Scatter PLot Sepal vs Petal Length", fontsize=8)

ax3.hist(X['sepal length (cm)'], bins=10, color="skyblue", edgecolor="black")
ax3.set_title("Histogram Sepal Length", fontsize=8)

ax4.boxplot(X['petal length (cm)'], vert=False)
ax4.set_title("Box Plot Petal Length", fontsize=8)

plt.tight_layout()

# %%
plt.rc("figure", figsize=(10,8))
plt.rc("font", family="monospace", weight="bold", size=8)

# %%
plt.rcdefaults()
