# %% [markdown]
# OBJECT ORIENTED PROGRAMMING FOR DATA SCIENCE

# %%
# Simple Inheritance
# Base Class
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name} is Speaking")

# Derived Class
class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def speak(self):
        print(f"{self.breed} {self.name} is Barking!")


dogone = Dog("Lucy", "German Shepherd")
dogone.speak()
# Out:
# German Shepherd Lucy is Barking!

# %%
# Multiple Inheritance
class A:
    def show(self):
        print("A")

class B:
    def show(self):
        print("B")

class C(A, B):
    pass

c = C()
c.show()
# Out:
# A

# %%
# Method Resolution Order
C.mro()
# Out:
# [__main__.C, __main__.A, __main__.B, object]

# %%
# make a class called DataList, write a program that will compute the mean of the list
class DataList:
    def __init__(self, alist):
        self.alist = alist
    
    def mean(self):
        return sum(self.alist)/len(self.alist)

l1 = DataList([1, 2, 3, 4, 5])
l1.mean()
# Out:
# 3.0

# %% [markdown]
# # Exception Handling

# %%
while True:
    try:
        n1 = input("First Number? ")
        n2 = input("Second Number? ")

        if(n1=='q' or n2=='q'):
            break
        result = int(n1)/int(n2)
        print("Result is ", result)
    except ZeroDivisionError:
        print("Cannot divide by zero, fuck you")
    except ValueError:
        print("Please enter valid number")
    finally:
        print("This always runs..")
# Out:
# Result is  0.5
# This always runs..
# This always runs..

# %%
aList = [1, 2, 3, 4, 5]
while (True):
    aList.pop()
